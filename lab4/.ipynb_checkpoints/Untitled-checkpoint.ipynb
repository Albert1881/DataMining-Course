# %% [markdown]
# # Date

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
CSV_FILE_PATH = './landslide_catalog.csv'
df = pd.read_csv(CSV_FILE_PATH)
df.head(5)
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
# 3         Quebec       42786       Châteauguay   2.98682  ...
# 4       Kentucky        6903         Pikeville   5.66542  ...
#
#                                  geolocation  hazard_type      landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide           Landslide
# 1  (40.517499999999998, -81.430499999999995)    Landslide           Landslide
# 2             (40.4377, -79.915999999999997)    Landslide           Landslide
# 3  (45.322600000000001, -73.777100000000004)    Landslide  Riverbank collapse
# 4  (37.432499999999997, -82.493099999999998)    Landslide           Landslide
#
#   landslide_size   trigger storm_name injuries fatalities  \
# 0          Small      Rain        NaN      NaN        NaN
# 1          Small      Rain        NaN      NaN        NaN
# 2          Small      Rain        NaN      NaN        NaN
# 3          Small      Rain        NaN      NaN        NaN
# 4          Small  Downpour        NaN      NaN        0.0
#
#                   source_name  \
# 0                  NBC 4 news
# 1              Canton Rep.com
# 2  The Pittsburgh Channel.com
# 3                   Le Soleil
# 4      Matthew Crawford (KGS)
#
#                                          source_link
# 0      http://www.nbc4.com/news/11186871/detail.html
# 1  http://www.cantonrep.com/index.php?ID=345054&C...
# 2  https://web.archive.org/web/20080423132842/htt...
# 3  http://www.hebdos.net/lsc/edition162007/articl...
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
df.loc[[1,2,3],'date']
# Out:
# 1    3/22/07
# 2     4/6/07
# 3    4/14/07
# Name: date, dtype: object

# %%
df['date_parsed'] = pd.to_datetime(df['date'], infer_datetime_format = True, utc = True)

# %%
df.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ... hazard_type  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...   Landslide
# 1           Ohio       17288  New Philadelphia   3.33522  ...   Landslide
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...   Landslide
# 3         Quebec       42786       Châteauguay   2.98682  ...   Landslide
# 4       Kentucky        6903         Pikeville   5.66542  ...   Landslide
#
#        landslide_type  landslide_size   trigger storm_name injuries  \
# 0           Landslide           Small      Rain        NaN      NaN
# 1           Landslide           Small      Rain        NaN      NaN
# 2           Landslide           Small      Rain        NaN      NaN
# 3  Riverbank collapse           Small      Rain        NaN      NaN
# 4           Landslide           Small  Downpour        NaN      NaN
#
#   fatalities                 source_name  \
# 0        NaN                  NBC 4 news
# 1        NaN              Canton Rep.com
# 2        NaN  The Pittsburgh Channel.com
# 3        NaN                   Le Soleil
# 4        0.0      Matthew Crawford (KGS)
#
#                                          source_link               date_parsed
# 0      http://www.nbc4.com/news/11186871/detail.html 2007-03-02 00:00:00+00:00
# 1  http://www.cantonrep.com/index.php?ID=345054&C... 2007-03-22 00:00:00+00:00
# 2  https://web.archive.org/web/20080423132842/htt... 2007-04-06 00:00:00+00:00
# 3  http://www.hebdos.net/lsc/edition162007/articl... 2007-04-14 00:00:00+00:00
# 4                                                NaN 2007-04-15 00:00:00+00:00
#
# [5 rows x 24 columns]

# %%
day_of_month_df = df['date_parsed'].dt.day

# %%
sns.displot(day_of_month_df, kde=False, bins=31)

# %% [markdown]
# # Character Encoding

# %%
import chardet  
import urllib

# %%
before = "This is the euro symbol: €"
after=before.encode("ascii",errors="replace")
print(after.decode("ascii"))
# Out:
# This is the euro symbol: ?

# %%
with open("ks-projects-201612.csv",'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))
print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
kickstarter_2016 = pd.read_csv("ks-projects-201612.csv",encoding='Windows-1252')
kickstarter_2016.head()
# Out:
# C:\Users\albert\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (13,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           ID                                               name   \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000004038                                     Where is Hank?
# 2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4  1000014025                               Monarch Espresso Bar
#
#         category  main_category  currency             deadline   goal   \
# 0          Poetry     Publishing       GBP  2015-10-09 11:36:00   1000
# 1  Narrative Film   Film & Video       USD  2013-02-26 00:20:50  45000
# 2           Music          Music       USD  2012-04-16 04:24:11   5000
# 3    Film & Video   Film & Video       USD  2015-08-29 01:00:00  19500
# 4     Restaurants           Food       USD  2016-04-01 13:38:27  50000
#
#              launched  pledged       state  backers  country  usd pledged   \
# 0  2015-08-11 12:12:28        0      failed        0       GB            0
# 1  2013-01-12 00:20:50      220      failed        3       US          220
# 2  2012-03-17 03:24:11        1      failed        1       US            1
# 3  2015-07-04 08:35:03     1283    canceled       14       US         1283
# 4  2016-02-26 13:38:27    52375  successful      224       US        52375
#
#   Unnamed: 13 Unnamed: 14 Unnamed: 15  Unnamed: 16
# 0         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN          NaN

# %%
kickstarter_2016.iloc[:,[13,14,15,16]].notnull()
# Out:
#         Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0              True         True         True         True
# 1              True         True         True         True
# 2              True         True         True         True
# 3              True         True         True         True
# 4              True         True         True         True
# ...             ...          ...          ...          ...
# 323745         True         True         True         True
# 323746         True         True         True         True
# 323747         True         True         True         True
# 323748         True         True         True         True
# 323749         True         True         True         True
#
# [323750 rows x 4 columns]

# %%
kickstarter_2016[(kickstarter_2016.iloc[:,[13,14,15,16]].notnull().T.any())] #https://www.jb51.net/article/169635.htm
# Out:
#                ID                                name   \
# 13795   1081139420                  The Rolling Stones
# 16482   1097082409                           Pixel art
# 61447   1365419849                                 VIA
# 104120  1618382802  Druid Hill Park Passport: Discover
# 112934  1670090635            EXCALIBRE:Sword of Truth
# 145502  1864561559                             T-shirt
# 225692   410977509     Handmade Artisan Soaps: Natural
# 243349   516522480                      American Booty
# 264243   642928449                  FRANCIS - The Pope
# 269970   677103185                        SixSixSeven
# 275186   708058934                             Be Wise
# 305503   890269949    Community Clothing. Make Clothes
#
#                                  category            main_category   \
# 13795                      BEGGARS BANQUET   50 Years in the Making
# 16482                         personalized        Retro Gaming art.
# 61447    ME (V.isual I.nteractive A.rchive       M.ercury E.dition)
# 104120                               Enjoy                    Learn
# 112934                       Path of Light       Kingdom of Heaven.
# 145502                        dress shirts                    pants
# 225692                              Gentle       Good for your skin
# 243349        USA-made products Series One                  Spirits
# 264243                        Buenos Aires                   soccer
# 269970                             Angels                   Demons
# 275186                         Wear Wisdom            Divine Wisdom
# 305503                         Create Jobs            Restore Pride
#
#                  currency      deadline            goal             launched   \
# 13795                 Rock         Music             USD  2011-08-12 01:17:48
# 16482               Crafts        Crafts             USD  2016-07-28 21:36:59
# 61447             Software    Technology             USD  2016-03-19 20:40:23
# 104120          Be active!    Publishing      Publishing                  USD
# 112934          Nonfiction    Publishing             USD  2016-04-01 08:00:00
# 145502    clothing company       Apparel         Fashion                  USD
# 225692              Crafts        Crafts             USD  2015-10-08 22:08:39
# 243349            Painting           Art             USD  2013-02-02 03:45:14
# 264243   tango and culture  Film & Video    Film & Video                  USD
# 269970           Religion       Esoteric  Graphic Novels               Comics
# 275186             Apparel       Fashion             USD  2015-02-27 13:53:56
# 305503             Fashion       Fashion             GBP  2016-03-16 16:24:27
#
#                    pledged                state              backers   \
# 13795                  4625  2011-06-04 01:17:48                   20
# 16482                   500  2016-06-28 21:36:59                    0
# 61447                 10000  2016-02-18 21:40:23                   26
# 104120  2012-07-28 01:30:00                 9500  2012-06-06 23:54:14
# 112934                24000  2016-02-22 21:57:30                    1
# 145502  2015-08-02 18:23:23                20000  2015-07-03 18:23:23
# 225692                  200  2015-09-08 22:08:39                  435
# 243349                 1776  2013-01-03 03:45:14                  401
# 264243  2014-03-02 23:34:00                75000  2014-02-05 02:06:20
# 269970                  USD  2015-10-10 01:00:00                  750
# 275186                10000  2015-01-28 13:53:56                    1
# 305503                75000  2016-02-15 17:24:27              88619.2
#
#                    country  usd pledged  Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 13795                failed            2          US          20         NaN
# 16482                failed            0          US           0         NaN
# 61447                failed            2          US          26         NaN
# 104120                 9854   successful         208          US        9854
# 112934               failed            1          US           1         NaN
# 145502                    0       failed           0          US           0
# 225692           successful           10          US         435         NaN
# 243349               failed            7          US         401         NaN
# 264243                    0       failed           0          US           0
# 269970  2015-09-10 18:15:45           25      failed           1          US
# 275186               failed            1          US           1         NaN
# 305503           successful         1020          GB      128535         NaN
#
#         Unnamed: 16
# 13795           NaN
# 16482           NaN
# 61447           NaN
# 104120          NaN
# 112934          NaN
# 145502          NaN
# 225692          NaN
# 243349          NaN
# 264243          NaN
# 269970         25.0
# 275186          NaN
# 305503          NaN

# %% [markdown]
# # Duplication

# %%
df_with_dups = pd.read_csv("Reviews.csv")

# %%
df_sorted = df_with_dups.sort_values(by='ProductId',ascending=True)

# %%
subset=["ProductId", "UserId", "ProfileName", "Time"]

# %%
df_sorted.drop_duplicates(subset=subset, keep='first', inplace=True)

# %%
print("Data retained after deduplication:", len(df_sorted)/len(df_with_dups))
# Out:
# Data retained after deduplication: 0.9926326492557005
